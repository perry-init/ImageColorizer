# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from skimage import io, color
import torch

from Color import Colorizer, generate_colored_image
# Out:
# C:\Users\Utente\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
device = torch.device("cuda:0" if True and torch.cuda.is_available() else "cpu")

model = Colorizer()
# Notation bs(batch size) ds(dataset size) img(image resizing)
model.load_state_dict(torch.load('./models/color_bs128_ds20000_img256.pth'))
model = model.to(device)

# %%
generate_colored_image('./img/bw_doggo.jpg', model, device, target_size=(512, 512))
